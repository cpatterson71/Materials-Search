# %%
import streamlit as st
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %%
excel = pd.read_excel('Materials_Database.xlsx', index_col='Client')
temp = pd.DataFrame(excel)
temp.head()
# Out:
#         Process   R  LPIPN       Recd   Item/Product #  \
# Client
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-01          96-2670
# ADJ     ProcessA  R    NaN 2021-02-01          96-2670
#
#                       Material Description              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
#
#              Manufacturer         LPI-Batch     Batch Expire/Re-test  \
# Client
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ            Sklar Corp  RM-01022021-0001    300012            Exp
# ADJ            Sklar Corp  RM-01022021-0001    300012            Exp
#
#          Expiration/Re-test Initial Balance  UOM  Removed  Qty Returned  Qty  \
# Client
# ADJ     2025-11-18 00:00:00             500  PCS             0           NaN
# ADJ     2025-11-18 00:00:00             NaN  PCS            50           NaN
# ADJ     2025-11-18 00:00:00             NaN  PCS            50           NaN
# ADJ     2023-07-28 00:00:00              50  PCS           NaN           NaN
# ADJ     2023-07-28 00:00:00                  PCS             3           NaN
#
#        Balance        Checkout Date Initials Additional Information
# Client
# ADJ          0  2021-02-18 00:00:00      RPH      Released in Stock
# ADJ        NaN  2021-02-18 00:00:00       RS              GMP Batch
# ADJ        NaN  2021-03-01 00:00:00       MC               Shipping
# ADJ          0  2021-02-03 00:00:00      RPH      Released in Stock
# ADJ        NaN  2021-02-12 00:00:00       MC        ADJ 690mL Batch

# %%
tests = temp[' Expiration/Re-test'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp[' Expiration/Re-test']= dates

temp.head()
# Out:
#         Process   R  LPIPN       Recd   Item/Product #  \
# Client
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-01          96-2670
# ADJ     ProcessA  R    NaN 2021-02-01          96-2670
#
#                       Material Description              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
#
#              Manufacturer         LPI-Batch     Batch Expire/Re-test  \
# Client
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ            Sklar Corp  RM-01022021-0001    300012            Exp
# ADJ            Sklar Corp  RM-01022021-0001    300012            Exp
#
#         Expiration/Re-test Initial Balance  UOM  Removed  Qty Returned  Qty  \
# Client
# ADJ             2025-11-18             500  PCS             0           NaN
# ADJ             2025-11-18             NaN  PCS            50           NaN
# ADJ             2025-11-18             NaN  PCS            50           NaN
# ADJ             2023-07-28              50  PCS           NaN           NaN
# ADJ             2023-07-28                  PCS             3           NaN
#
#        Balance        Checkout Date Initials Additional Information
# Client
# ADJ          0  2021-02-18 00:00:00      RPH      Released in Stock
# ADJ        NaN  2021-02-18 00:00:00       RS              GMP Batch
# ADJ        NaN  2021-03-01 00:00:00       MC               Shipping
# ADJ          0  2021-02-03 00:00:00      RPH      Released in Stock
# ADJ        NaN  2021-02-12 00:00:00       MC        ADJ 690mL Batch

# %%
tests = temp['Checkout Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp['Checkout Date']= dates

temp.head()
# Out:
#         Process   R  LPIPN       Recd   Item/Product #  \
# Client
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-01          96-2670
# ADJ     ProcessA  R    NaN 2021-02-01          96-2670
#
#                       Material Description              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
#
#              Manufacturer         LPI-Batch     Batch Expire/Re-test  \
# Client
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ     Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ            Sklar Corp  RM-01022021-0001    300012            Exp
# ADJ            Sklar Corp  RM-01022021-0001    300012            Exp
#
#         Expiration/Re-test Initial Balance  UOM  Removed  Qty Returned  Qty  \
# Client
# ADJ             2025-11-18             500  PCS             0           NaN
# ADJ             2025-11-18             NaN  PCS            50           NaN
# ADJ             2025-11-18             NaN  PCS            50           NaN
# ADJ             2023-07-28              50  PCS           NaN           NaN
# ADJ             2023-07-28                  PCS             3           NaN
#
#        Balance Checkout Date Initials Additional Information
# Client
# ADJ          0    2021-02-18      RPH      Released in Stock
# ADJ        NaN    2021-02-18       RS              GMP Batch
# ADJ        NaN    2021-03-01       MC               Shipping
# ADJ          0    2021-02-03      RPH      Released in Stock
# ADJ        NaN    2021-02-12       MC        ADJ 690mL Batch

# %%
temp.dropna(subset=['Balance'], inplace=True)
temp.head()
# Out:
#         Process   R  LPIPN       Recd   Item/Product #  \
# Client
# ADJ     ProcessA  R    NaN 2021-02-16  0553859B/430791
# ADJ     ProcessA  R    NaN 2021-02-01          96-2670
# ADJ     ProcessA  R    NaN 2020-12-28           H93811
# ADJ     ProcessA  R    NaN 2021-02-23    844181/305181
# ADJ     ProcessA  R    NaN 2021-02-23  1482618B/305198
#
#                       Material Description              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ       Repeater Pump TUBE Sets, Sterile             Medline
# ADJ       NEEDLE, Hypo 18G x 1" Blunt Fill    McKesson Medical
# ADJ          NEEDLE, Sterile 16G x 1  1/2"  Fisher Scientific
#
#                    Manufacturer         LPI-Batch     Batch Expire/Re-test  \
# Client
# ADJ           Fisher Scientific  RM-16022021-0005  32320044            Exp
# ADJ                  Sklar Corp  RM-01022021-0001    300012            Exp
# ADJ     Baxter Healthcare Corp.               NaN  60257097            Exp
# ADJ                          BD  RM-23022021-0001   0281779            Exp
# ADJ                          BD  RM-23022021-0004   0143349            Exp
#
#         Expiration/Re-test Initial Balance  UOM  Removed  Qty Returned  Qty  \
# Client
# ADJ             2025-11-18             500  PCS             0           NaN
# ADJ             2023-07-28              50  PCS           NaN           NaN
# ADJ             2023-08-31              10  PCS           NaN           NaN
# ADJ             2025-11-30             100  PCS           NaN           NaN
# ADJ             2025-07-31             100  PCS           NaN           NaN
#
#        Balance Checkout Date Initials Additional Information
# Client
# ADJ          0    2021-02-18      RPH      Released in Stock
# ADJ          0    2021-02-03      RPH      Released in Stock
# ADJ          0    2020-12-29      RPH      Released In Stock
# ADJ          0    2021-02-23      RPH      Released in Stock
# ADJ          0    2021-02-23      RPH      Released in Stock

# %%
temp = temp.loc[:,['Recd', 'Item/Product #', 'Material Description', 'Vendor', 'Manufacturer', 'LPI-Batch', 'Batch', ' Expiration/Re-test', 'Initial Balance', 'UOM', 'Balance']]
temp.head()
# Out:
#              Recd   Item/Product #                Material Description  \
# Client
# ADJ    2021-02-16  0553859B/430791       CentrifugeTUBE , 15mL Sterile
# ADJ    2021-02-01          96-2670  Dressing Forceps, 5 & 1/2, Sterile
# ADJ    2020-12-28           H93811    Repeater Pump TUBE Sets, Sterile
# ADJ    2021-02-23    844181/305181    NEEDLE, Hypo 18G x 1" Blunt Fill
# ADJ    2021-02-23  1482618B/305198       NEEDLE, Sterile 16G x 1  1/2"
#
#                     Vendor             Manufacturer         LPI-Batch  \
# Client
# ADJ      Fisher Scientific        Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific                Sklar Corp  RM-01022021-0001
# ADJ                Medline  Baxter Healthcare Corp.               NaN
# ADJ       McKesson Medical                       BD  RM-23022021-0001
# ADJ     Fisher Scientific                        BD  RM-23022021-0004
#
#            Batch  Expiration/Re-test Initial Balance  UOM Balance
# Client
# ADJ     32320044          2025-11-18             500  PCS       0
# ADJ       300012          2023-07-28              50  PCS       0
# ADJ     60257097          2023-08-31              10  PCS       0
# ADJ      0281779          2025-11-30             100  PCS       0
# ADJ      0143349          2025-07-31             100  PCS       0

# %%
temp.to_csv('Materials Database.csv')

# %%
file = 'Materials Database.csv'
data = pd.read_csv(file, index_col=False)
df = pd.DataFrame(data)

st.title('Materials Database')
# Out:
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
@st.cache
def load_data():
    df = pd.read_csv('Materials Database.csv')
    return df

df = load_data()

# %%
def search(df, column, search_term):
    if column == 'Material Name':
        search_term = (search_term)
        
    indexes = df.loc[df[column].isin([search_term])].index
    if indexes.size > 0:
        return df.iloc[indexes]
    else:
        return[]

# %%
buffer, col2, col3 = st.columns([1, 20, 40])

with col2:
    key = st.selectbox("Key",['Client','Item/Product #','Material Name', 'Vendor', 'Manufacturer', 'LPI-Lot Number', 'Initial Balance', 'Removed Qty', 'Returned Qty', 'Balance', 'Checkout Date'])

with col3:
    search_term = st.text_input("Search")
    if key != '' and search_term != '':
        df = search(data, key, search_term)

buffer, col2 = st.columns([1, 100])

with col2:
    if not df.empty:
        st.dataframe(df)
    else:
        st.write('Did not find any matching criteria')
