# %%
import streamlit as st
import pandas as pd
import numpy as np
from datetime import datetime as dt

# %%
excel = pd.read_excel('Materials_Database.xlsx', index_col='Client')
temp = pd.DataFrame(excel)
temp.head()
# Out:
#        Raw Material Type R/Q  LPI-Part Number  Recd Date   Item/Product #  \
# Client
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-01          96-2670
# ADJ             ProcessA   R              NaN 2021-02-01          96-2670
#
#                              Material Name              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
#
#              Manufacturer    LPI-Lot Number  \
# Client
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ            Sklar Corp  RM-01022021-0001
# ADJ            Sklar Corp  RM-01022021-0001
#
#        Batch/                   Lot Number Exp/Re-test      Exp/Retest Date  \
# Client
# ADJ                               32320044         Exp  2025-11-18 00:00:00
# ADJ                               32320044         Exp  2025-11-18 00:00:00
# ADJ                               32320044         Exp  2025-11-18 00:00:00
# ADJ                                 300012         Exp  2023-07-28 00:00:00
# ADJ                                 300012         Exp  2023-07-28 00:00:00
#
#        Initial Balance  UOM  Removed  Qty Returned  Qty Balance  \
# Client
# ADJ                500  PCS             0           NaN       0
# ADJ                NaN  PCS            50           NaN     NaN
# ADJ                NaN  PCS            50           NaN     NaN
# ADJ                 50  PCS           NaN           NaN       0
# ADJ                     PCS             3           NaN     NaN
#
#               Checkout Date Initials           Comments
# Client
# ADJ     2021-02-18 00:00:00      RPH  Released in Stock
# ADJ     2021-02-18 00:00:00       RS          GMP Batch
# ADJ     2021-03-01 00:00:00       MC           Shipping
# ADJ     2021-02-03 00:00:00      RPH  Released in Stock
# ADJ     2021-02-12 00:00:00       MC    ADJ 690mL Batch

# %%
tests = temp['Exp/Retest Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp['Exp/Retest Date']= dates

temp.head()
# Out:
#        Raw Material Type R/Q  LPI-Part Number  Recd Date   Item/Product #  \
# Client
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-01          96-2670
# ADJ             ProcessA   R              NaN 2021-02-01          96-2670
#
#                              Material Name              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
#
#              Manufacturer    LPI-Lot Number  \
# Client
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ            Sklar Corp  RM-01022021-0001
# ADJ            Sklar Corp  RM-01022021-0001
#
#        Batch/                   Lot Number Exp/Re-test Exp/Retest Date  \
# Client
# ADJ                               32320044         Exp      2025-11-18
# ADJ                               32320044         Exp      2025-11-18
# ADJ                               32320044         Exp      2025-11-18
# ADJ                                 300012         Exp      2023-07-28
# ADJ                                 300012         Exp      2023-07-28
#
#        Initial Balance  UOM  Removed  Qty Returned  Qty Balance  \
# Client
# ADJ                500  PCS             0           NaN       0
# ADJ                NaN  PCS            50           NaN     NaN
# ADJ                NaN  PCS            50           NaN     NaN
# ADJ                 50  PCS           NaN           NaN       0
# ADJ                     PCS             3           NaN     NaN
#
#               Checkout Date Initials           Comments
# Client
# ADJ     2021-02-18 00:00:00      RPH  Released in Stock
# ADJ     2021-02-18 00:00:00       RS          GMP Batch
# ADJ     2021-03-01 00:00:00       MC           Shipping
# ADJ     2021-02-03 00:00:00      RPH  Released in Stock
# ADJ     2021-02-12 00:00:00       MC    ADJ 690mL Batch

# %%
tests = temp['Checkout Date'].astype(str)
dates = []
for test in tests:
    dates.append(test[:-9])

temp['Checkout Date']= dates

temp.head()
# Out:
#        Raw Material Type R/Q  LPI-Part Number  Recd Date   Item/Product #  \
# Client
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-01          96-2670
# ADJ             ProcessA   R              NaN 2021-02-01          96-2670
#
#                              Material Name              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
#
#              Manufacturer    LPI-Lot Number  \
# Client
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific  RM-16022021-0005
# ADJ            Sklar Corp  RM-01022021-0001
# ADJ            Sklar Corp  RM-01022021-0001
#
#        Batch/                   Lot Number Exp/Re-test Exp/Retest Date  \
# Client
# ADJ                               32320044         Exp      2025-11-18
# ADJ                               32320044         Exp      2025-11-18
# ADJ                               32320044         Exp      2025-11-18
# ADJ                                 300012         Exp      2023-07-28
# ADJ                                 300012         Exp      2023-07-28
#
#        Initial Balance  UOM  Removed  Qty Returned  Qty Balance Checkout Date  \
# Client
# ADJ                500  PCS             0           NaN       0    2021-02-18
# ADJ                NaN  PCS            50           NaN     NaN    2021-02-18
# ADJ                NaN  PCS            50           NaN     NaN    2021-03-01
# ADJ                 50  PCS           NaN           NaN       0    2021-02-03
# ADJ                     PCS             3           NaN     NaN    2021-02-12
#
#        Initials           Comments
# Client
# ADJ         RPH  Released in Stock
# ADJ          RS          GMP Batch
# ADJ          MC           Shipping
# ADJ         RPH  Released in Stock
# ADJ          MC    ADJ 690mL Batch

# %%
temp.dropna(subset=['Balance'], inplace=True)
temp.head()
# Out:
#        Raw Material Type R/Q  LPI-Part Number  Recd Date   Item/Product #  \
# Client
# ADJ             ProcessA   R              NaN 2021-02-16  0553859B/430791
# ADJ             ProcessA   R              NaN 2021-02-01          96-2670
# ADJ             ProcessA   R              NaN 2020-12-28           H93811
# ADJ             ProcessA   R              NaN 2021-02-23    844181/305181
# ADJ             ProcessA   R              NaN 2021-02-23  1482618B/305198
#
#                              Material Name              Vendor  \
# Client
# ADJ          CentrifugeTUBE , 15mL Sterile   Fisher Scientific
# ADJ     Dressing Forceps, 5 & 1/2, Sterile  Fisher Scientific
# ADJ       Repeater Pump TUBE Sets, Sterile             Medline
# ADJ       NEEDLE, Hypo 18G x 1" Blunt Fill    McKesson Medical
# ADJ          NEEDLE, Sterile 16G x 1  1/2"  Fisher Scientific
#
#                    Manufacturer    LPI-Lot Number  \
# Client
# ADJ           Fisher Scientific  RM-16022021-0005
# ADJ                  Sklar Corp  RM-01022021-0001
# ADJ     Baxter Healthcare Corp.               NaN
# ADJ                          BD  RM-23022021-0001
# ADJ                          BD  RM-23022021-0004
#
#        Batch/                   Lot Number Exp/Re-test Exp/Retest Date  \
# Client
# ADJ                               32320044         Exp      2025-11-18
# ADJ                                 300012         Exp      2023-07-28
# ADJ                               60257097         Exp      2023-08-31
# ADJ                                0281779         Exp      2025-11-30
# ADJ                                0143349         Exp      2025-07-31
#
#        Initial Balance  UOM  Removed  Qty Returned  Qty Balance Checkout Date  \
# Client
# ADJ                500  PCS             0           NaN       0    2021-02-18
# ADJ                 50  PCS           NaN           NaN       0    2021-02-03
# ADJ                 10  PCS           NaN           NaN       0    2020-12-29
# ADJ                100  PCS           NaN           NaN       0    2021-02-23
# ADJ                100  PCS           NaN           NaN       0    2021-02-23
#
#        Initials           Comments
# Client
# ADJ         RPH  Released in Stock
# ADJ         RPH  Released in Stock
# ADJ         RPH  Released In Stock
# ADJ         RPH  Released in Stock
# ADJ         RPH  Released in Stock

# %%
temp = temp.loc[:,['R/Q', 'Recd Date', 'Item/Product #', 'Material Name', 'Vendor', 'Manufacturer', 'LPI-Lot Number', 'Exp/Retest Date', 'Initial Balance', 'UOM', 'Balance']]
temp.head()
# Out:
#        R/Q  Recd Date   Item/Product #                       Material Name  \
# Client
# ADJ      R 2021-02-16  0553859B/430791       CentrifugeTUBE , 15mL Sterile
# ADJ      R 2021-02-01          96-2670  Dressing Forceps, 5 & 1/2, Sterile
# ADJ      R 2020-12-28           H93811    Repeater Pump TUBE Sets, Sterile
# ADJ      R 2021-02-23    844181/305181    NEEDLE, Hypo 18G x 1" Blunt Fill
# ADJ      R 2021-02-23  1482618B/305198       NEEDLE, Sterile 16G x 1  1/2"
#
#                     Vendor             Manufacturer    LPI-Lot Number  \
# Client
# ADJ      Fisher Scientific        Fisher Scientific  RM-16022021-0005
# ADJ     Fisher Scientific                Sklar Corp  RM-01022021-0001
# ADJ                Medline  Baxter Healthcare Corp.               NaN
# ADJ       McKesson Medical                       BD  RM-23022021-0001
# ADJ     Fisher Scientific                        BD  RM-23022021-0004
#
#        Exp/Retest Date Initial Balance  UOM Balance
# Client
# ADJ         2025-11-18             500  PCS       0
# ADJ         2023-07-28              50  PCS       0
# ADJ         2023-08-31              10  PCS       0
# ADJ         2025-11-30             100  PCS       0
# ADJ         2025-07-31             100  PCS       0

# %%
temp.to_csv('Materials Database.csv')

# %%
file = 'Materials Database.csv'
data = pd.read_csv(file, index_col='Client')
df = pd.DataFrame(data)

st.title('Materials Database')
# Out:
# 2023-01-26 16:19:36.423
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\carlp\Anaconda3\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# DeltaGenerator(_root_container=0, _provided_cursor=None, _parent=None, _block_type=None, _form_data=None)

# %%
@st.cache
def load_data():
    df = pd.read_csv('Materials Database.csv')
    return df

df = load_data()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in to_bytes(self, obj, context)
#     359             # Hash the input
# --> 360             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     361
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in _to_bytes(self, obj, context)
#     625             assert code is not None
# --> 626             if self._file_should_be_hashed(code.co_filename):
#     627                 context = _get_context(obj)
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in _file_should_be_hashed(self, filename)
#     401         return file_util.file_is_in_folder_glob(
# --> 402             filepath, self._get_main_script_directory()
#     403         ) or file_util.file_in_pythonpath(filepath)
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in _get_main_script_directory()
#     713         # script path in ScriptRunner.
# --> 714         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715         return str(abs_main_path.parent)
#
# AttributeError: module '__main__' has no attribute '__file__'
#
# During handling of the above exception, another exception occurred:
#
# InternalHashError                         Traceback (most recent call last)
# <ipython-input-9-8c3edf53887d> in <module>
#       4     return df
#       5
# ----> 6 df = load_data()
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\caching.py in wrapped_func(*args, **kwargs)
#     625         if show_spinner:
#     626             with spinner(message):
# --> 627                 return get_or_create_cached_value()
#     628         else:
#     629             return get_or_create_cached_value()
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\caching.py in get_or_create_cached_value()
#     550                 # If we generated the key earlier we would only hash those
#     551                 # globals by name, and miss changes in their code or value.
# --> 552                 cache_key = _hash_func(non_optional_func, hash_funcs)
#     553
#     554             # First, get the cache that's attached to this function.
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\caching.py in _hash_func(func, hash_funcs)
#     677     # because this step will be hashing any objects referenced in the function
#     678     # body.
# --> 679     update_hash(
#     680         func,
#     681         hasher=func_hasher,
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in update_hash(val, hasher, hash_reason, hash_source, context, hash_funcs)
#     106
#     107     ch = _CodeHasher(hash_funcs)
# --> 108     ch.update(hasher, val, context)
#     109
#     110
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in update(self, hasher, obj, context)
#     383     def update(self, hasher, obj: Any, context: Optional[Context] = None) -> None:
#     384         """Update the provided hasher with the hash of an object."""
# --> 385         b = self.to_bytes(obj, context)
#     386         hasher.update(b)
#     387
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in to_bytes(self, obj, context)
#     372
#     373         except Exception as ex:
# --> 374             raise InternalHashError(ex, obj)
#     375
#     376         finally:
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in to_bytes(self, obj, context)
#     358         try:
#     359             # Hash the input
# --> 360             b = b"%s:%s" % (tname, self._to_bytes(obj, context))
#     361
#     362             # Hmmm... It's possible that the size calculation is wrong. When we
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in _to_bytes(self, obj, context)
#     624             code = getattr(obj, "__code__", None)
#     625             assert code is not None
# --> 626             if self._file_should_be_hashed(code.co_filename):
#     627                 context = _get_context(obj)
#     628                 defaults = getattr(obj, "__defaults__", None)
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in _file_should_be_hashed(self, filename)
#     400             return False
#     401         return file_util.file_is_in_folder_glob(
# --> 402             filepath, self._get_main_script_directory()
#     403         ) or file_util.file_in_pythonpath(filepath)
#     404
#
# ~\Anaconda3\lib\site-packages\streamlit\runtime\legacy_caching\hashing.py in _get_main_script_directory()
#     712         # This works because we set __main__.__file__ to the
#     713         # script path in ScriptRunner.
# --> 714         abs_main_path = pathlib.Path(__main__.__file__).resolve()
#     715         return str(abs_main_path.parent)
#     716
#
# InternalHashError: module '__main__' has no attribute '__file__'
#
# While caching the body of `load_data()`, Streamlit encountered an
# object of type `builtins.function`, which it does not know how to hash.
#
# **In this specific case, it's very likely you found a Streamlit bug so please
# [file a bug report here.]
# (https://github.com/streamlit/streamlit/issues/new/choose)**
#
# In the meantime, you can try bypassing this error by registering a custom
# hash function via the `hash_funcs` keyword in @st.cache(). For example:
#
# ```
# @st.cache(hash_funcs={builtins.function: my_hash_func})
# def my_func(...):
#     ...
# ```
#
# If you don't know where the object of type `builtins.function` is coming
# from, try looking at the hash chain below for an object that you do recognize,
# then pass that to `hash_funcs` instead:
#
# ```
# Object of type builtins.function: <function load_data at 0x0000021220F28CA0>
# ```
#
# Please see the `hash_funcs` [documentation](https://docs.streamlit.io/library/advanced-features/caching#the-hash_funcs-parameter)
# for more details.

# %%
def search(df, column, search_term):
    if column == 'Client':
        search_term = (search_term)
        
    indexes = df.loc[df[column].isin([search_term])].index
    if indexes.size > 0:
        return df.iloc[indexes]
    else:
        return[]

# %%
buffer, col2, col3 = st.columns([1, 20, 40])

with col2:
    key = st.selectbox("Key",['Client','Recd Date','Item/Product #','Material Name', 'Vendor', 'Manufacturer', 'LPI-Lot Number', 'Initial Balance', 'Removed Qty', 'Returned Qty', 'Balance', 'Checkout Date'])

with col3:
    search_term = st.text_input("Search")
    if key != '' and search_term != '':
        df = search(data, key, search_term)

buffer, col2 = st.columns([1, 100])

with col2:
    if not df.empty:
        st.dataframe(df)
    else:
        st.write('Did not find any matching criteria')
